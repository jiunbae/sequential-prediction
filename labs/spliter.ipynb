# %%
import pandas as pd

# %%
train = pd.read_csv('../data/train.csv')

# %%
train.loc[train['P2(Holiday)'] != 4., 'P2(Holiday)'] = 0
train.loc[train['P2(Holiday)'] == 4., 'P2(Holiday)'] = 1

# %%
train
# Out:
#        Month  Day  Hour  Quarter  P1(DayOfWeek)  P2(Holiday)  P3(HighestTemp)  \
# 0          1    1     0        1              7            0             10.7
# 1          1    1     0        2              7            0             10.7
# 2          1    1     0        3              7            0             10.7
# 3          1    1     1        0              7            0             10.7
# 4          1    1     1        1              7            0             10.7
# ...      ...  ...   ...      ...            ...          ...              ...
# 34837     12   31    23        0              7            0              5.6
# 34838     12   31    23        1              7            0              5.6
# 34839     12   31    23        2              7            0              5.6
# 34840     12   31    23        3              7            0              5.6
# 34841     12   31    24        0              7            0              5.6
#
#        P4(Weather)  Demand
# ...
